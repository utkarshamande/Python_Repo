# %%
#import pandas
import pandas as pd

# %%
#read file as excel
df = pd.read_excel('/Talegaon gat animal information.xlsx')

# %%
#print 1st five rows bydefault
df.head()
# Out:
#   Unnamed: 0          Unnamed: 1 Unnamed: 2      Unnamed: 3        Unnamed: 4
# 0     sr no      name of farmer    village   no of animals   milk production
# 1        NaN             ajampur        NaN             NaN               NaN
# 2          1   Aditya Anil Dighe    ajampur              13                65
# 3          2  Anil Navnath Dighe    ajampur              14                70
# 4          3  Anil Somnath Dighe    ajampur               2                10

# %%
#print last 5 rows
df.tail()
# Out:
#      Unnamed: 0              Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4
# 3143        167  VITTHAL MADHAV SUPEKAR  Wadzari kh          7         35
# 3144        168   YOGESH DATTATRYA KALE  Wadzari kh          3         15
# 3145        169          YOGESH SUPEKAR  Wadzari kh          2         10
# 3146        170   YUVRAJ GANPAT SUPEKAR  Wadzari kh          3         15
# 3147        NaN                   Total         NaN        727       3635

# %%
#print how many rows and columns are avilable
df.shape
# Out:
# (3148, 5)

# %%
#information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3148 entries, 0 to 3147
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3118 non-null   object
#  1   Unnamed: 1  3148 non-null   object
#  2   Unnamed: 2  3118 non-null   object
#  3   Unnamed: 3  3133 non-null   object
#  4   Unnamed: 4  3146 non-null   object
# dtypes: object(5)
# memory usage: 123.1+ KB

# %%
#statistical info
df.describe()
# Out:
#         Unnamed: 0 Unnamed: 1        Unnamed: 2  Unnamed: 3  Unnamed: 4
# count         3118       3148              3118        3133        3146
# unique         416       3126                16          44          45
# top             49      Total  Chincholi Gurav            2          10
# freq            15         15               415         757         757

# %%
#col names
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
#check how many null values
df.isnull().sum()
# Out:
# Unnamed: 0    30
# Unnamed: 1     0
# Unnamed: 2    30
# Unnamed: 3    15
# Unnamed: 4     2
# dtype: int64

# %%
#rename columns name
df.rename(columns={"Unnamed: 0":"S.No",
                    "Unnamed: 1":"name_of_farmer",
                    "Unnamed: 2":"village",
                    "Unnamed: 3":"no_of_animal",
                    "Unnamed: 4":"milk_production"},
           inplace=True)

# %%
df
# Out:
#         S.No          name_of_farmer     village    no_of_animal  \
# 0     sr no          name of farmer     village   no of animals
# 1        NaN                 ajampur         NaN             NaN
# 2          1       Aditya Anil Dighe     ajampur              13
# 3          2      Anil Navnath Dighe     ajampur              14
# 4          3      Anil Somnath Dighe     ajampur               2
# ...      ...                     ...         ...             ...
# 3143     167  VITTHAL MADHAV SUPEKAR  Wadzari kh               7
# 3144     168   YOGESH DATTATRYA KALE  Wadzari kh               3
# 3145     169          YOGESH SUPEKAR  Wadzari kh               2
# 3146     170   YUVRAJ GANPAT SUPEKAR  Wadzari kh               3
# 3147     NaN                   Total         NaN             727
#
#        milk_production
# 0     milk production
# 1                  NaN
# 2                   65
# 3                   70
# 4                   10
# ...                ...
# ...

# %%
#check total null values
df.isnull().sum().sum()
# Out:
# 77

# %%
#drop null values
df.dropna(axis=0, how='all', inplace=True)
df.dropna(axis=1, how='all', inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 77

# %%
#fill 0 very null value
df.fillna(0,inplace=True)

# %%
#check null value
df.isnull().sum()
# Out:
# S.No               0
# name_of_farmer     0
# village            0
# no_of_animal       0
# milk_production    0
# dtype: int64

# %%
df
# Out:
#         S.No          name_of_farmer     village    no_of_animal  \
# 0     sr no          name of farmer     village   no of animals
# 1          0                 ajampur           0               0
# 2          1       Aditya Anil Dighe     ajampur              13
# 3          2      Anil Navnath Dighe     ajampur              14
# 4          3      Anil Somnath Dighe     ajampur               2
# ...      ...                     ...         ...             ...
# 3143     167  VITTHAL MADHAV SUPEKAR  Wadzari kh               7
# 3144     168   YOGESH DATTATRYA KALE  Wadzari kh               3
# 3145     169          YOGESH SUPEKAR  Wadzari kh               2
# 3146     170   YUVRAJ GANPAT SUPEKAR  Wadzari kh               3
# 3147       0                   Total           0             727
#
#        milk_production
# 0     milk production
# 1                    0
# 2                   65
# 3                   70
# 4                   10
# ...                ...
# ...

# %%
#drop o index row
df.drop(index=0,inplace=True)

# %%
df
# Out:
#      S.No            name_of_farmer     village no_of_animal milk_production
# 1       0                   ajampur           0            0               0
# 2       1         Aditya Anil Dighe     ajampur           13              65
# 3       2        Anil Navnath Dighe     ajampur           14              70
# 4       3        Anil Somnath Dighe     ajampur            2              10
# 5       4  Ashok Sakharam Kandalkar     ajampur            4              20
# ...   ...                       ...         ...          ...             ...
# 3143  167    VITTHAL MADHAV SUPEKAR  Wadzari kh            7              35
# 3144  168     YOGESH DATTATRYA KALE  Wadzari kh            3              15
# 3145  169            YOGESH SUPEKAR  Wadzari kh            2              10
# 3146  170     YUVRAJ GANPAT SUPEKAR  Wadzari kh            3              15
# 3147    0                     Total           0          727            3635
#
# [3147 rows x 5 columns]

# %%
#drop 1 index row
df.drop(index=1,inplace=True)

# %%
df
# Out:
#      S.No            name_of_farmer     village no_of_animal milk_production
# 2       1         Aditya Anil Dighe     ajampur           13              65
# 3       2        Anil Navnath Dighe     ajampur           14              70
# 4       3        Anil Somnath Dighe     ajampur            2              10
# 5       4  Ashok Sakharam Kandalkar     ajampur            4              20
# 6       5   Babasaheb Kondaji Dighe     ajampur           12              60
# ...   ...                       ...         ...          ...             ...
# 3143  167    VITTHAL MADHAV SUPEKAR  Wadzari kh            7              35
# 3144  168     YOGESH DATTATRYA KALE  Wadzari kh            3              15
# 3145  169            YOGESH SUPEKAR  Wadzari kh            2              10
# 3146  170     YUVRAJ GANPAT SUPEKAR  Wadzari kh            3              15
# 3147    0                     Total           0          727            3635
#
# [3146 rows x 5 columns]

# %%
#check rows and columns
df.shape
# Out:
# (3146, 5)

# %%
#check duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
#reset index
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      S.No            name_of_farmer     village no_of_animal milk_production
# 0       1         Aditya Anil Dighe     ajampur           13              65
# 1       2        Anil Navnath Dighe     ajampur           14              70
# 2       3        Anil Somnath Dighe     ajampur            2              10
# 3       4  Ashok Sakharam Kandalkar     ajampur            4              20
# 4       5   Babasaheb Kondaji Dighe     ajampur           12              60
# ...   ...                       ...         ...          ...             ...
# 3141  167    VITTHAL MADHAV SUPEKAR  Wadzari kh            7              35
# 3142  168     YOGESH DATTATRYA KALE  Wadzari kh            3              15
# 3143  169            YOGESH SUPEKAR  Wadzari kh            2              10
# 3144  170     YUVRAJ GANPAT SUPEKAR  Wadzari kh            3              15
# 3145    0                     Total           0          727            3635
#
# [3146 rows x 5 columns]

# %%
df.to_excel("Talegaon gat animal information.xlsx", index=False)

# %%
from google.colab import files

# Download the file
files.download("/Talegaon gat animal information.xlsx")
